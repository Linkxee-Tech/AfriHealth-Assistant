# %% [markdown]
# # Model Testing
# Test llama.cpp inference speed and output quality.

# %%
import sys; sys.path.insert(0,'..')
from backend.core.llm_engine import llm_engine
llm_engine.load_model()
print(llm_engine.get_status())
