# %% [markdown]
# # AfriHealth Data Exploration
# Explore the raw medical datasets before building the knowledge base.

# %%
import sys; sys.path.insert(0,'..') 
from knowledge_base.data_loader import data_loader
files = data_loader.scan_files()
print(f'Found {len(files)} documents')
